# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import glob as glob
import statsmodels.api as sm
import pandas as pd
from sklearn import linear_model
from sklearn import metrics
import statsmodels.api as sm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
from scipy.optimize import minimize
from sklearn.preprocessing import PolynomialFeatures
import itertools
from sklearn.metrics import mean_squared_error
from scipy.spatial import ConvexHull
import seaborn as sns

class ShapeSence:
    def loadData(self):
        # rawdata/下からcsvデータを読み込む
        files =  glob.glob('cleanData/ShapeSenceAverage.csv')
        width = pd.DataFrame()
        height = pd.DataFrame()
        gx = pd.DataFrame()
        gy = pd.DataFrame()
        for f in files:
            df = pd.read_csv(f, header=0)
            wdf = df[["p1","p2","p3","width"]]
            hdf = df[["p1","p2","p3","height"]]
            gydf = df[["p1","p2","p3","Gy"]]
            width = pd.concat([width,wdf])
            height = pd.concat([height,hdf])
            gy = pd.concat([gy,gydf])
        self.Y_width = width["width"]
        self.Y_height = height["height"]
        self.Y_gy = gy["Gy"]
        self.X_width = width.drop("width",axis=1)
        self.X_height = height.drop("height",axis=1)
        self.X_gy = gy.drop("Gy",axis=1)
    
    # n:回帰の次元
    def regression(self,n):
        # 回帰に用いる変数設定 https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html
        poly = PolynomialFeatures(degree=n) #n次回帰
        self.dim = n
        width = poly.fit_transform(self.X_width) #widthに対応するw,h,gx,gyのn次交差？を取得
        height = poly.fit_transform(self.X_height)
        gy = poly.fit_transform(self.X_gy)

        # width, heightが定数項を含んでいるので fit_intercept = False でOK
        model_width = linear_model.LinearRegression(fit_intercept=False)
        model_height = linear_model.LinearRegression(fit_intercept=False)
        model_gy = linear_model.LinearRegression(fit_intercept=False)
        
        model_width.fit(width,self.Y_width)
        model_height.fit(height,self.Y_height)
        model_gy.fit(gy,self.Y_gy)

        self.width_coef = model_width.coef_
        self.height_coef = model_height.coef_
        self.gy_coef = model_gy.coef_
        
        self.R2_width = model_width.score(width,self.Y_width)
        self.R2_height = model_width.score(height,self.Y_height)
        self.R2_gy = model_width.score(gy,self.Y_gy)
        
    def printError(self):
        predictWidth = []
        predictHeight = []
        predictGy = []
        for i ,row in self.X_width.iterrows():
            predictWidth.append(self.predictWidth([row[0],row[1],row[2]]))
        print('MSE width : %.3f' % mean_squared_error(self.Y_width,predictWidth))
        print('R^2 width : %.3f' % self.R2_width)

        for i ,row in self.X_height.iterrows():
            predictHeight.append(self.predictHeight([row[0],row[1],row[2]]))
        print('MSE height : %.3f' % mean_squared_error(self.Y_height,predictHeight))
        print('R^2 height : %.3f' % self.R2_height)
        
        for i ,row in self.X_gy.iterrows():
            predictGy.append(self.predictGy([row[0],row[1],row[2]]))
        print('MSE gy : %.3f' % mean_squared_error(self.Y_gy,predictGy))
        print('R^2 gy : %.3f' % self.R2_gy)
#         print('R^2 width : %.3f' % (mod.score(X_train, y_train), mod.score(X_test, y_test)))

    
    # shape:目標形状[width,height,Gy](*cm)
    def optimize(self,shape):
        self.shape = [shape[0]/10,shape[1]/10,shape[2]/10]
        cons = ({"type":"ineq","fun":lambda x : x[0]},
        {"type":"ineq","fun":lambda x : 180 - x[0]},
        {"type":"ineq","fun":lambda x : x[1]},
        {"type":"ineq","fun":lambda x : x[0] - x[1]},
        {"type":"ineq","fun":lambda x : 90 - (x[0] - x[1])},
        {"type":"ineq","fun":lambda x : x[2]},
        {"type":"ineq","fun":lambda x : x[1] - x[2]},
        {"type":"ineq","fun":lambda x : 90 - (x[1] - x[2])})

        res = minimize(self.costfunc,[0,0,0],method="COBYLA",constraints=cons)
        # [costfuncの値,min costfunc を与える x]
        return [res.fun,res.x]

    def predictHeight(self,x):
        # x[0]:p, x[1]:theta
        x = [x]
        poly = PolynomialFeatures(degree=self.dim)
        x = poly.fit_transform(x)
        predict_height = np.dot(x,self.height_coef)
        return predict_height[0]

    def predictWidth(self,x):
        x = [x]
        poly = PolynomialFeatures(degree=self.dim)
        x = poly.fit_transform(x)
        predict_width = np.dot(x,self.width_coef)
        return predict_width[0]

    def predictGy(self,x):
        x = [x]
        poly = PolynomialFeatures(degree=self.dim)
        x = poly.fit_transform(x)
        predict_gy = np.dot(x,self.gy_coef)
        return predict_gy[0]

    def costfunc(self,x):
        return ((self.shape[0] - self.predictWidth(x))**2 + (self.shape[1] - self.predictHeight(x))**2 + (self.shape[2] - self.predictGy(x))**2)

    def showWidthGraph(self):
        x_surf, y_surf = np.meshgrid(np.linspace(0, 125, 100),np.linspace(0, 90, 100))
        onlyX = pd.DataFrame({0: x_surf.ravel(), 1: y_surf.ravel()}) #メッシュを作成
        predictY = []
        for index, row in onlyX.iterrows():
            predictY.append(self.predictWidth([row[0],row[1]]))
        predictY = np.array(predictY)
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.set_xlabel('p')
        ax.set_ylabel('theta')
        ax.set_zlabel('W')
        ax.set_xlim([0, 125])
        ax.set_ylim([0, 90])
        ax.scatter(self.X_width["length"],self.X_width["angle"],self.Y_width,
               marker='.', c =[1.0,1.0,1.0,0.0], edgecolors=[0,0.5,1,0.5], alpha = 0.5, facecolors='none') # Marker Style
        surf = ax.plot_surface(x_surf,y_surf,predictY.reshape(x_surf.shape),
                           cmap=cm.viridis, alpha=1.0,
                           linewidth=0.2, edgecolors='black')
        ax.view_init(azim = -150, elev = 30)
        # Add a color bar which maps values to colors.
        # fig.colorbar(surf, shrink=0.5, aspect=5)
        fig.set_size_inches(6, 8)
        # show
        plt.show()
        #Save to svg
        fig.savefig("image/width.svg")

    def showHeightGraph(self):
        x_surf, y_surf = np.meshgrid(np.linspace(0, 125, 100),np.linspace(0, 90, 100))
        onlyX = pd.DataFrame({0: x_surf.ravel(), 1: y_surf.ravel()}) #メッシュを作成
        predictY = []
        for index, row in onlyX.iterrows():
            predictY.append(self.predictHeight([row[0],row[1]]))
        predictY = np.array(predictY)
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.set_xlabel('p')
        ax.set_ylabel('theta')
        ax.set_zlabel('H')
        ax.set_xlim([0, 125])
        ax.set_ylim([0, 90])
        ax.scatter(self.X_height["length"],self.X_height["angle"],self.Y_height,
               marker='.', c =[1.0,1.0,1.0,0.0], edgecolors=[0,0.5,1,0.5], alpha = 0.5, facecolors='none') # Marker Style
        surf = ax.plot_surface(x_surf,y_surf,predictY.reshape(x_surf.shape),
                           cmap=cm.viridis, alpha=1.0,
                           linewidth=0.2, edgecolors='black')
        ax.view_init(azim = -150, elev = 30)
        # Add a color bar which maps values to colors.
        # fig.colorbar(surf, shrink=0.5, aspect=5)
        fig.set_size_inches(6, 8)
        # show
        plt.show()
        #Save to svg
        fig.savefig('image/height.svg')
    
    # Transcaliburのカバーエリア(VR空間上で一定の損失で再現できる範囲)の提示関数
    # 重いです...
    # SEP 分割数：SEP * SEP に分割して最適化する
    def showCoverAreaOriginal(self,SEP):
        W = []
        H = []
        SEPARATE = SEP
        ERROR_THRESHOLD = 1
        w = np.linspace(5,100,SEPARATE)
        h = np.linspace(5,100,SEPARATE)
        k = 0
        for i,j in itertools.product(w,h):
            try:
                error_value = self.optimize([i,j,j/2])[0]
            except:
                print("error")
            k = k+1
            if error_value < ERROR_THRESHOLD :
                W.append(i)
                H.append(j)
            print ("calculating..." + str(int(k*100.0/SEPARATE/SEPARATE)) + "%" + "finished" + str(error_value))
        W = np.array(W)
        H = np.array(H)
        W = W / 2
        W = np.append(W,-W)
        H = np.append(H,H)
        print(W,H)
        plt.plot(W,H,".")
        plt.xlabel("Width[cm]")
        plt.ylabel("Height[cm]")
        plt.xlim([-50,50])
        plt.ylim([0,80])
        plt.savefig("image/cover_area.svg")
        plt.title("Covering area of Transcalibur in VR")
        plt.show()
        
    def calcAreaError(self,SEP):
        self.SEP = SEP
        SEPARATE = SEP
        self.areaMIN = 0
        self.areaMAX = 60
        self.Error_Values = np.zeros((SEPARATE,SEPARATE))
        k = 0
        for i in range(SEPARATE):
            w = (self.areaMAX - self.areaMIN) / (SEPARATE-1) * i + self.areaMIN
            for j in range(SEPARATE):
                h = (self.areaMAX - self.areaMIN) / (SEPARATE-1) * j + self.areaMIN
                try:
                    error_value = self.optimize([w,h,h/2])[0]
                except:
                    print("error")
                    error_value = 99999
                self.Error_Values[i][j] = error_value
                k=k+1
                print(("caluculating...") + str(int(k*100.0/SEPARATE/SEPARATE)) + "%" + "finished" + str(error_value))
        print("finish caluculation!")
                
    def showCoverArea(self, ERROR_THRESHOLD):
        W,H = np.where(self.Error_Values<ERROR_THRESHOLD)
        W = (W *(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN)/2
        W = np.append(W,-W)
        H = np.append(H,H)*(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN
        #print(W,H)
        plt.plot(W,H,".")
        plt.xlabel("Width[cm]")
        plt.ylabel("Height[cm]")
        plt.xlim([-50,50])
        plt.ylim([0,80])
        plt.savefig("image/cover_area.svg")
        plt.title("Covering area of ShapeSence in VR")
        plt.show()
        
        
    def showHull(self, ERROR_THRESHOLD_LIST):
        W,H = np.where(self.Error_Values<ERROR_THRESHOLD_LIST[0])
        W = (W *(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN)/2
        W = np.array(W)
        H = np.array(H)*(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN
        points = np.array([W,H]).T
        hull = ConvexHull(points)
        #plt.plot(points[:,0], points[:,1], '.')
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], linestyle='solid',c='darkblue')
        #plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=2)
        #plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
        
        W,H = np.where(self.Error_Values<ERROR_THRESHOLD_LIST[1])
        W = (W *(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN)/2
        W = np.array(W)
        H = np.array(H)*(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN
        points = np.array([W,H]).T
        hull = ConvexHull(points)
        #plt.plot(points[:,0], points[:,1], 'o')
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], linestyle='solid',c='blue')
        #plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=2)
        #plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
        
        W,H = np.where(self.Error_Values<ERROR_THRESHOLD_LIST[2])
        W = (W *(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN)/2
        W = np.array(W)
        H = np.array(H)*(self.areaMAX - self.areaMIN)/(self.SEP-1)+self.areaMIN
        points = np.array([W,H]).T
        hull = ConvexHull(points)
        #plt.plot(points[:,0], points[:,1], 'o')
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], linestyle='solid',c='lightblue')
        #plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=2)
        #plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
        
        
        plt.xlim([-40,40])
        plt.ylim([-10,60])
        plt.savefig("image/cover_area_ShapeSence.svg")
        plt.show()
        
    def showHeatMap(self):
        error_values = np.array(self.Error_Values).T[::-1]
        plt.figure(figsize=(3,6))
        sns.heatmap(error_values, vmin=0,vmax=5,cmap='Reds',cbar=False)
        plt.axis('off')
        plt.savefig("image/heatmap_ShapeSense.svg")
        plt.show()

# %%
# 初期化
shapeSence = ShapeSence()

# %%
# データのロード
shapeSence.loadData()

# %%
# 回帰の実行
shapeSence.regression(3)

# %%
shapeSence.optimize([20,20,10]) 
#最適なp1, p2(mm), theta1, theta2(degree) とその時のErrorを表示
# Out:
# [0.48774174188993097, array([ 0.,  0.,  0.])]

# %%
shapeSence.calcAreaError(100)
# Out:
# caluculating...0%finished13.2491641909
# caluculating...0%finished12.9152028689
# caluculating...0%finished12.5904242835
# caluculating...0%finished12.2748284344
# caluculating...0%finished11.9684153219
# caluculating...0%finished11.6711849457
# caluculating...0%finished11.3831373061
# caluculating...0%finished11.1042724029
# caluculating...0%finished10.8345902361
# caluculating...0%finished10.5740908058
# caluculating...0%finished10.322774112
# caluculating...0%finished10.0806401546
# caluculating...0%finished9.84768893367
# caluculating...0%finished9.62392044919
# caluculating...0%finished9.40933470118
# caluculating...0%finished9.20393168961
# caluculating...0%finished9.00771141451
# caluculating...0%finished8.82067387585
# caluculating...0%finished8.64281907366
# caluculating...0%finished8.47414700792
# caluculating...0%finished8.31465767863
# caluculating...0%finished8.1643510858
# caluculating...0%finished8.02322722942
# caluculating...0%finished7.89128610951
# caluculating...0%finished7.76852772604
# caluculating...0%finished7.65495207903
# caluculating...0%finished7.55055916848
# caluculating...0%finished7.45534899438
# caluculating...0%finished7.36932155674
# caluculating...0%finished7.29247685555
# caluculating...0%finished7.22481489082
# caluculating...0%finished7.16633566255
# caluculating...0%finished7.11703917073
# caluculating...0%finished7.07692541536
# caluculating...0%finished7.04599439645
# caluculating...0%finished7.024246114
# caluculating...0%finished7.011680568
# caluculating...0%finished7.00829775846
# caluculating...0%finished7.01409768537
# caluculating...0%finished7.02908034874
# caluculating...0%finished7.05324574856
# caluculating...0%finished7.08659388484
# caluculating...0%finished7.12912475758
# caluculating...0%finished7.18083836677
# caluculating...0%finished7.24173471241
# caluculating...0%finished7.31181379451
# caluculating...0%finished7.39107561307
# caluculating...0%finished7.47952016808
# caluculating...0%finished7.57714745955
# caluculating...0%finished7.68395748747
# caluculating...0%finished7.79995025185
# caluculating...0%finished7.92512575268
# caluculating...0%finished8.05948398997
# caluculating...0%finished8.20302496372
# caluculating...0%finished8.35574867392
# caluculating...0%finished8.51765512057
# caluculating...0%finished8.68874430368
# caluculating...0%finished8.56175136379
# caluculating...0%finished8.6495030142
# caluculating...0%finished8.73856618354
# caluculating...0%finished8.82964395603
# caluculating...0%finished8.92335428197
# caluculating...0%finished7.54672809953
# caluculating...0%finished7.53065860582
# caluculating...0%finished7.51730948552
# caluculating...0%finished7.50678100119
# caluculating...0%finished7.49916556361
# caluculating...0%finished7.4945465526
# caluculating...0%finished7.49299751182
# caluculating...0%finished7.49458172586
# caluculating...0%finished7.49935215329
# caluculating...0%finished7.50735166603
# caluculating...0%finished7.518613527
# caluculating...0%finished7.53316204124
# caluculating...0%finished7.5510133158
# caluculating...0%finished7.57217607565
# caluculating...0%finished7.5966524929
# caluculating...0%finished7.62443899892
# caluculating...0%finished7.65552705784
# caluculating...0%finished7.68990388852
# caluculating...0%finished7.72755312733
# caluculating...0%finished7.76845542969
# caluculating...0%finished7.81258901062
# caluculating...0%finished7.85993012649
# caluculating...0%finished7.9104535016
# caluculating...0%finished7.96413270368
# caluculating...0%finished8.02094047274
# caluculating...0%finished8.08084900765
# caluculating...0%finished8.14383021431
# caluculating...0%finished8.20985592007
# caluculating...0%finished8.27889805689
# caluculating...0%finished8.35092881824
# caluculating...0%finished8.42592079064
# caluculating...0%finished8.5038470648
# caluculating...0%finished8.58468132724
# caluculating...0%finished8.66839793491
# caluculating...0%finished8.75497197635
# caluculating...0%finished8.8443793182
# caluculating...0%finished8.93734176736
# caluculating...1%finished9.038616701
# caluculating...1%finished12.9319529317
# caluculating...1%finished12.5979916098
# caluculating...1%finished12.2732130243
# caluculating...1%finished11.9576171753
# caluculating...1%finished11.6512040627
# caluculating...1%finished11.3539736866
# caluculating...1%finished11.0659260469
# caluculating...1%finished10.7870611437
# caluculating...1%finished10.517378977
# caluculating...1%finished10.2568795467
# caluculating...1%finished10.0055628528
# caluculating...1%finished9.76342889544
# caluculating...1%finished9.53047767451
# caluculating...1%finished9.30670919003
# caluculating...1%finished9.09212344202
# caluculating...1%finished8.88672043045
# caluculating...1%finished8.69050015535
# caluculating...1%finished8.50346261669
# caluculating...1%finished8.3256078145
# caluculating...1%finished8.15693574876
# caluculating...1%finished7.99744641947
# caluculating...1%finished7.84713982664
# caluculating...1%finished7.70601597027
# caluculating...1%finished7.57407485035
# caluculating...1%finished7.45131646688
# caluculating...1%finished7.33774081987
# caluculating...1%finished7.23334790932
# caluculating...1%finished7.13813773522
# caluculating...1%finished7.05211029758
# caluculating...1%finished6.9752655964
# caluculating...1%finished6.90760363166
# caluculating...1%finished6.84912440339
# caluculating...1%finished6.79982791157
# caluculating...1%finished6.7597141562
# caluculating...1%finished6.72878313729
# caluculating...1%finished6.70703485484
# caluculating...1%finished6.69446930884
# caluculating...1%finished6.6910864993
# caluculating...1%finished6.69688642621
# caluculating...1%finished6.71186908958
# caluculating...1%finished6.7360344894
# caluculating...1%finished6.76938262568
# caluculating...1%finished6.81191349842
# caluculating...1%finished6.86362710761
# caluculating...1%finished6.92452345325
# caluculating...1%finished6.99460253535
# caluculating...1%finished7.07386435391
# caluculating...1%finished7.16230890892
# caluculating...1%finished7.25993620039
# caluculating...1%finished7.36674622831
# caluculating...1%finished7.48273899269
# caluculating...1%finished7.60791449352
# caluculating...1%finished7.74227273081
# caluculating...1%finished7.88581370456
# caluculating...1%finished8.03853741476
# caluculating...1%finished8.20044386141
# caluculating...1%finished8.37153304453
# caluculating...1%finished8.21940307296
# caluculating...1%finished8.30550486363
# caluculating...1%finished8.39304974766
# caluculating...1%finished8.48271345689
# caluculating...1%finished8.57509560196
# caluculating...1%finished7.21789930078
# caluculating...1%finished7.20207763623
# caluculating...1%finished7.18893025163
# caluculating...1%finished7.17855734632
# caluculating...1%finished7.17105135712
# caluculating...1%finished7.16649573645
# caluculating...1%finished7.16496410891
# caluculating...1%finished7.16651981915
# caluculating...1%finished7.17121584652
# caluculating...1%finished7.17909503441
# caluculating...1%finished7.19019056883
# caluculating...1%finished7.20452663518
# caluculating...1%finished7.22211918869
# caluculating...1%finished7.24297678307
# caluculating...1%finished7.2671014133
# caluculating...1%finished7.29448934078
# caluculating...1%finished7.32513187863
# caluculating...1%finished7.35901612356
# caluculating...1%finished7.39612562721
# caluculating...1%finished7.43644100439
# caluculating...1%finished7.47994047816
# caluculating...1%finished7.52660036503
# caluculating...1%finished7.57639550333
# caluculating...1%finished7.6292996295
# caluculating...1%finished7.68528570655
# caluculating...1%finished7.74432620944
# caluculating...1%finished7.80639337159
# caluculating...1%finished7.87145939661
# caluculating...1%finished7.93949663898
# caluculating...1%finished8.01047775763
# caluculating...1%finished8.08437584421
# caluculating...1%finished8.16116453088
# caluculating...1%finished8.2408180781
# caluculating...1%finished8.32331144637
# caluculating...1%finished8.40862035303
# caluculating...1%finished8.49672131608
# caluculating...1%finished8.58913190821
# caluculating...2%finished8.69040173531
# caluculating...2%finished12.6220878617
# caluculating...2%finished12.2881265398
# caluculating...2%finished11.9633479543
# caluculating...2%finished11.6477521053
# caluculating...2%finished11.3413389927
# caluculating...2%finished11.0441086166
# caluculating...2%finished10.7560609769
# caluculating...2%finished10.4771960737
# caluculating...2%finished10.207513907
# caluculating...2%finished9.94701447667
# caluculating...2%finished9.69569778283
# caluculating...2%finished9.45356382544
# caluculating...2%finished9.22061260451
# caluculating...2%finished8.99684412004
# caluculating...2%finished8.78225837202
# caluculating...2%finished8.57685536046
# caluculating...2%finished8.38063508535
# caluculating...2%finished8.1935975467
# caluculating...2%finished8.0157427445
# caluculating...2%finished7.84707067876
# caluculating...2%finished7.68758134948
# caluculating...2%finished7.53727475665
# caluculating...2%finished7.39615090027
# caluculating...2%finished7.26420978035
# caluculating...2%finished7.14145139689
# caluculating...2%finished7.02787574988
# caluculating...2%finished6.92348283933
# caluculating...2%finished6.82827266523
# caluculating...2%finished6.74224522759
# caluculating...2%finished6.6654005264
# caluculating...2%finished6.59773856167
# caluculating...2%finished6.53925933339
# caluculating...2%finished6.48996284157
# caluculating...2%finished6.44984908621
# caluculating...2%finished6.4189180673
# caluculating...2%finished6.39716978485
# caluculating...2%finished6.38460423885
# caluculating...2%finished6.3812214293
# caluculating...2%finished6.38702135622
# caluculating...2%finished6.40200401959
# caluculating...2%finished6.42616941941
# caluculating...2%finished6.45951755569
# caluculating...2%finished6.50204842842
# caluculating...2%finished6.55376203761
# caluculating...2%finished6.61465838326
# caluculating...2%finished6.68473746536
# caluculating...2%finished6.76399928392
# caluculating...2%finished6.85244383893
# caluculating...2%finished6.9500711304
# caluculating...2%finished7.05688115832
# caluculating...2%finished7.1728739227
# caluculating...2%finished7.29804942353
# caluculating...2%finished7.43240766082
# caluculating...2%finished7.57594863456
# caluculating...2%finished7.72867234476
# caluculating...2%finished7.89057879142
# caluculating...2%finished7.80039629888
# caluculating...2%finished7.88405670321
# caluculating...2%finished7.96853508634
# caluculating...2%finished8.05457952224
# caluculating...2%finished8.14284134184
# caluculating...2%finished6.91449738097
# caluculating...2%finished6.89640543711
# caluculating...2%finished6.88083496823
# caluculating...2%finished6.86789214179
# caluculating...2%finished6.85767704865
# caluculating...2%finished6.85028211428
# caluculating...2%finished6.84579083231
# caluculating...2%finished6.84427688299
# caluculating...2%finished6.84580365079
# caluculating...2%finished6.85042411911
# caluculating...2%finished6.85818109082
# caluculating...2%finished6.86910766515
# caluculating...2%finished6.88322790208
# caluculating...2%finished6.90055760214
# caluculating...2%finished6.92110514843
# caluculating...2%finished6.94487236301
# caluculating...2%finished6.97185534493
# caluculating...2%finished7.00204526724
# caluculating...2%finished7.03542911919
# caluculating...2%finished7.07199038554
# caluculating...2%finished7.11170966112
# caluculating...2%finished7.15456520064
# caluculating...2%finished7.20053340668
# caluculating...2%finished7.24958925966
# caluculating...2%finished7.30170669452
# caluculating...2%finished7.35685892857
# caluculating...2%finished7.41501874519
# caluculating...2%finished7.47615873818
# caluculating...2%finished7.54025152119
# caluculating...2%finished7.60726990491
# caluculating...2%finished7.67718704715
# caluculating...2%finished7.74997657808
# caluculating...2%finished7.82561270391
# caluculating...2%finished7.90407029119
# caluculating...2%finished7.98532493482
# caluculating...2%finished8.06935301102
# caluculating...2%finished8.15613171823
# caluculating...2%finished8.24826705943
# caluculating...3%finished8.349531756
# caluculating...3%finished12.3195689809
# caluculating...3%finished11.985607659
# caluculating...3%finished11.6608290735
# caluculating...3%finished11.3452332244
# caluculating...3%finished11.0388201119
# caluculating...3%finished10.7415897358
# caluculating...3%finished10.4535420961
# caluculating...3%finished10.1746771929
# caluculating...3%finished9.90499502613
# caluculating...3%finished9.64449559584
# caluculating...3%finished9.393178902
# caluculating...3%finished9.15104494461
# caluculating...3%finished8.91809372368
# caluculating...3%finished8.69432523921
# caluculating...3%finished8.47973949119
# caluculating...3%finished8.27433647963
# caluculating...3%finished8.07811620452
# caluculating...3%finished7.89107866587
# caluculating...3%finished7.71322386367
# caluculating...3%finished7.54455179793
# caluculating...3%finished7.38506246864
# caluculating...3%finished7.23475587581
# caluculating...3%finished7.09363201944
# caluculating...3%finished6.96169089952
# caluculating...3%finished6.83893251606
# caluculating...3%finished6.72535686905
# caluculating...3%finished6.6209639585
# caluculating...3%finished6.5257537844
# caluculating...3%finished6.43972634676
# caluculating...3%finished6.36288164557
# caluculating...3%finished6.29521968084
# caluculating...3%finished6.23674045256
# caluculating...3%finished6.18744396074
# caluculating...3%finished6.14733020538
# caluculating...3%finished6.11639918647
# caluculating...3%finished6.09465090402
# caluculating...3%finished6.08208535802
# caluculating...3%finished6.07870254847
# caluculating...3%finished6.08450247539
# caluculating...3%finished6.09948513876
# caluculating...3%finished6.12365053858
# caluculating...3%finished6.15699867486
# caluculating...3%finished6.19952954759
# caluculating...3%finished6.25124315678
# caluculating...3%finished6.31213950243
# caluculating...3%finished6.38221858453
# caluculating...3%finished6.46148040309
# caluculating...3%finished6.5499249581
# caluculating...3%finished6.64755224956
# caluculating...3%finished6.75436227749
# caluculating...3%finished6.87035504187
# caluculating...3%finished6.9955305427
# caluculating...3%finished7.12988877999
# caluculating...3%finished7.27342975373
# caluculating...3%finished7.42615346393
# caluculating...3%finished7.58805991059
# caluculating...3%finished7.47380643778
# caluculating...3%finished7.55571812
# caluculating...3%finished7.63859696311
# caluculating...3%finished7.72315707903
# caluculating...3%finished6.62019180162
# caluculating...3%finished6.60003671983
# caluculating...3%finished6.58224628439
# caluculating...3%finished6.56693043886
# caluculating...3%finished6.55419504766
# caluculating...3%finished6.54414004592
# caluculating...3%finished6.53685780716
# caluculating...3%finished6.53243183341
# caluculating...3%finished6.5309358335
# caluculating...3%finished6.53243320988
# caluculating...3%finished6.53697693288
# caluculating...3%finished6.54460975113
# caluculating...3%finished6.55536466823
# caluculating...3%finished6.56926561191
# caluculating...3%finished6.58632822573
# caluculating...3%finished6.60656072335
# caluculating...3%finished6.62996475868
# caluculating...3%finished6.6565362771
# caluculating...3%finished6.68626632384
# caluculating...3%finished6.71914179656
# caluculating...3%finished6.75514613234
# caluculating...3%finished6.79425992837
# caluculating...3%finished6.83646149608
# caluculating...3%finished6.88172735163
# caluculating...3%finished6.93003264735
# caluculating...3%finished6.98135154803
# caluculating...3%finished7.03565755804
# caluculating...3%finished7.09292380283
# caluculating...3%finished7.15312327159
# caluculating...3%finished7.2162290223
# caluculating...3%finished7.28221435683
# caluculating...3%finished7.35105296675
# caluculating...3%finished7.42271905488
# caluculating...3%finished7.49718743498
# caluculating...3%finished7.5744336124
# caluculating...3%finished7.65443384814
# caluculating...3%finished7.73716520815
# caluculating...3%finished7.82264723269
# caluculating...3%finished7.91474718914
# caluculating...4%finished8.0160067323
# caluculating...4%finished12.0243962892
# caluculating...4%finished11.6904349673
# caluculating...4%finished11.3656563818
# caluculating...4%finished11.0500605328
# caluculating...4%finished10.7436474202
# caluculating...4%finished10.4464170441
# caluculating...4%finished10.1583694044
# caluculating...4%finished9.87950450122
# caluculating...4%finished9.60982233447
# caluculating...4%finished9.34932290417
# caluculating...4%finished9.09800621033
# caluculating...4%finished8.85587225295
# caluculating...4%finished8.62292103202
# caluculating...4%finished8.39915254754
# caluculating...4%finished8.18456679952
# caluculating...4%finished7.97916378796
# caluculating...4%finished7.78294351285
# caluculating...4%finished7.5959059742
# caluculating...4%finished7.418051172
# caluculating...4%finished7.24937910626
# caluculating...4%finished7.08988977698
# caluculating...4%finished6.93958318415
# caluculating...4%finished6.79845932777
# caluculating...4%finished6.66651820785
# caluculating...4%finished6.54375982439
# caluculating...4%finished6.43018417738
# caluculating...4%finished6.32579126683
# caluculating...4%finished6.23058109273
# caluculating...4%finished6.14455365509
# caluculating...4%finished6.0677089539
# caluculating...4%finished6.00004698917
# caluculating...4%finished5.9415677609
# caluculating...4%finished5.89227126908
# caluculating...4%finished5.85215751371
# caluculating...4%finished5.8212264948
# caluculating...4%finished5.79947821235
# caluculating...4%finished5.78691266635
# caluculating...4%finished5.78352985681
# caluculating...4%finished5.78932978372
# caluculating...4%finished5.80431244709
# caluculating...4%finished5.82847784691
# caluculating...4%finished5.86182598319
# caluculating...4%finished5.90435685593
# caluculating...4%finished5.95607046512
# caluculating...4%finished6.01696681076
# caluculating...4%finished6.08704589286
# caluculating...4%finished6.16630771142
# caluculating...4%finished6.25475226643
# caluculating...4%finished6.3523795579
# caluculating...4%finished6.45918958582
# caluculating...4%finished6.5751823502
# caluculating...4%finished6.70035785103
# caluculating...4%finished6.83471608832
# caluculating...4%finished6.97825706207
# caluculating...4%finished7.13098077227
# caluculating...4%finished7.0743089875
# caluculating...4%finished7.15419694263
# caluculating...4%finished7.23439244432
# caluculating...4%finished7.3156932839
# caluculating...4%finished6.33471853894
# caluculating...4%finished6.31270929944
# caluculating...4%finished6.29290655026
# caluculating...4%finished6.27542161304
# caluculating...4%finished6.26036388108
# caluculating...4%finished6.24783885831
# caluculating...4%finished6.23794627385
# caluculating...4%finished6.23077840703
# caluculating...4%finished6.22641873276
# caluculating...4%finished6.22494095979
# caluculating...4%finished6.22640848517
# caluculating...4%finished6.23087424818
# caluculating...4%finished6.23838092907
# caluculating...4%finished6.24896142545
# caluculating...4%finished6.26263952721
# caluculating...4%finished6.27943071832
# caluculating...4%finished6.29934304488
# caluculating...4%finished6.32237799834
# caluculating...4%finished6.3485313798
# caluculating...4%finished6.37779412054
# caluculating...4%finished6.41015304367
# caluculating...4%finished6.44559155938
# caluculating...4%finished6.48409029108
# caluculating...4%finished6.52562763374
# caluculating...4%finished6.57018024647
# caluculating...4%finished6.61772348471
# caluculating...4%finished6.66823177633
# caluculating...4%finished6.72167894694
# caluculating...4%finished6.77803849984
# caluculating...4%finished6.83728385479
# caluculating...4%finished6.8993885509
# caluculating...4%finished6.96432641713
# caluculating...4%finished7.03207171438
# caluculating...4%finished7.10259925341
# caluculating...4%finished7.17588449011
# caluculating...4%finished7.25190360188
# caluculating...4%finished7.33063354822
# caluculating...4%finished7.41205211579
# caluculating...4%finished7.49647788339
# caluculating...4%finished7.58857226438
# caluculating...5%finished7.68982663239
# caluculating...5%finished11.7365697867
# caluculating...5%finished11.4026084648
# caluculating...5%finished11.0778298793
# caluculating...5%finished10.7622340303
# caluculating...5%finished10.4558209177
# caluculating...5%finished10.1585905416
# caluculating...5%finished9.87054290192
# caluculating...5%finished9.59167799872
# caluculating...5%finished9.32199583196
# caluculating...5%finished9.06149640167
# caluculating...5%finished8.81017970783
# caluculating...5%finished8.56804575044
# caluculating...5%finished8.33509452951
# caluculating...5%finished8.11132604504
# caluculating...5%finished7.89674029702
# caluculating...5%finished7.69133728546
# caluculating...5%finished7.49511701035
# caluculating...5%finished7.3080794717
# caluculating...5%finished7.1302246695
# caluculating...5%finished6.96155260376
# caluculating...5%finished6.80206327448
# caluculating...5%finished6.65175668165
# caluculating...5%finished6.51063282527
# caluculating...5%finished6.37869170535
# caluculating...5%finished6.25593332189
# caluculating...5%finished6.14235767488
# caluculating...5%finished6.03796476433
# caluculating...5%finished5.94275459023
# caluculating...5%finished5.85672715259
# caluculating...5%finished5.7798824514
# caluculating...5%finished5.71222048667
# caluculating...5%finished5.65374125839
# caluculating...5%finished5.60444476657
# caluculating...5%finished5.56433101121
# caluculating...5%finished5.5333999923
# caluculating...5%finished5.51165170985
# caluculating...5%finished5.49908616385
# caluculating...5%finished5.49570335431
# caluculating...5%finished5.50150328122
# caluculating...5%finished5.51648594459
# caluculating...5%finished5.54065134441
# caluculating...5%finished5.57399948069
# caluculating...5%finished5.61653035342
# caluculating...5%finished5.66824396261
# caluculating...5%finished5.72914030826
# caluculating...5%finished5.79921939036
# caluculating...5%finished5.87848120892
# caluculating...5%finished5.96692576393
# caluculating...5%finished6.0645530554
# caluculating...5%finished6.17136308332
# caluculating...5%finished6.2873558477
# caluculating...5%finished6.41253134853
# caluculating...5%finished6.54688958582
# caluculating...5%finished6.69043055956
# caluculating...5%finished6.84315426976
# caluculating...5%finished6.7635459456
# caluculating...5%finished6.84157561522
# caluculating...5%finished6.92008412712
# caluculating...5%finished6.99982638094
# caluculating...5%finished6.03415846853
# caluculating...5%finished6.01255249349
# caluculating...5%finished5.99310657003
# caluculating...5%finished5.97593118767
# caluculating...5%finished5.96113512312
# caluculating...5%finished5.94882345941
# caluculating...5%finished5.93909566643
# caluculating...5%finished5.93204388426
# caluculating...5%finished5.92775152315
# caluculating...5%finished5.92629226095
# caluculating...5%finished5.92772946521
# caluculating...5%finished5.9321160239
# caluculating...5%finished5.93949453486
# caluculating...5%finished5.94989777922
# caluculating...5%finished5.96334940248
# caluculating...5%finished5.97986472758
# caluculating...5%finished5.99945163502
# caluculating...5%finished6.02211146043
# caluculating...5%finished6.04783987148
# caluculating...5%finished6.07662770025
# caluculating...5%finished6.10846171409
# caluculating...5%finished6.14332531855
# caluculating...5%finished6.1811991891
# caluculating...5%finished6.22206183268
# caluculating...5%finished6.26589008247
# caluculating...5%finished6.31265953002
# caluculating...5%finished6.36234490106
# caluculating...5%finished6.41492037866
# caluculating...5%finished6.4703598806
# caluculating...5%finished6.52863729492
# caluculating...5%finished6.58972667903
# caluculating...5%finished6.65360242635
# caluculating...5%finished6.72023940428
# caluculating...5%finished6.78961306741
# caluculating...5%finished6.86169954889
# caluculating...5%finished6.93647573268
# caluculating...5%finished7.01391930947
# caluculating...5%finished7.09400881822
# caluculating...5%finished7.17765347625
# caluculating...5%finished7.26974225094
# caluculating...6%finished7.37099142335
# caluculating...6%finished11.4560894734
# caluculating...6%finished11.1221281515
# caluculating...6%finished10.797349566
# caluculating...6%finished10.4817537169
# caluculating...6%finished10.1753406044
# caluculating...6%finished9.87811022825
# caluculating...6%finished9.59006258859
# caluculating...6%finished9.31119768538
# caluculating...6%finished9.04151551863
# caluculating...6%finished8.78101608833
# caluculating...6%finished8.52969939449
# caluculating...6%finished8.28756543711
# caluculating...6%finished8.05461421618
# caluculating...6%finished7.8308457317
# caluculating...6%finished7.61625998368
# caluculating...6%finished7.41085697212
# caluculating...6%finished7.21463669701
# caluculating...6%finished7.02759915836
# caluculating...6%finished6.84974435617
# caluculating...6%finished6.68107229042
# caluculating...6%finished6.52158296114
# caluculating...6%finished6.37127636831
# caluculating...6%finished6.23015251193
# caluculating...6%finished6.09821139201
# caluculating...6%finished5.97545300855
# caluculating...6%finished5.86187736154
# caluculating...6%finished5.75748445099
# caluculating...6%finished5.66227427689
# caluculating...6%finished5.57624683925
# caluculating...6%finished5.49940213806
# caluculating...6%finished5.43174017333
# caluculating...6%finished5.37326094506
# caluculating...6%finished5.32396445324
# caluculating...6%finished5.28385069787
# caluculating...6%finished5.25291967896
# caluculating...6%finished5.23117139651
# caluculating...6%finished5.21860585051
# caluculating...6%finished5.21522304097
# caluculating...6%finished5.22102296788
# caluculating...6%finished5.23600563125
# caluculating...6%finished5.26017103107
# caluculating...6%finished5.29351916735
# caluculating...6%finished5.33605004009
# caluculating...6%finished5.38776364928
# caluculating...6%finished5.44865999492
# caluculating...6%finished5.51873907702
# caluculating...6%finished5.59800089558
# caluculating...6%finished5.68644545059
# caluculating...6%finished5.78407274206
# caluculating...6%finished5.89088276998
# caluculating...6%finished6.00687553436
# caluculating...6%finished6.13205103519
# caluculating...6%finished6.26640927248
# caluculating...6%finished6.40995024623
# caluculating...6%finished6.383306053
# caluculating...6%finished6.45973741122
# caluculating...6%finished6.53594927425
# caluculating...6%finished6.61279701042
# caluculating...6%finished5.76412065196
# caluculating...6%finished5.74091879109
# caluculating...6%finished5.71972100565
# caluculating...6%finished5.70063646964
# caluculating...6%finished5.68377476727
# caluculating...6%finished5.66924398898
# caluculating...6%finished5.65714873332
# caluculating...6%finished5.64758815564
# caluculating...6%finished5.6406542082
# caluculating...6%finished5.63643019707
# caluculating...6%finished5.6349897364
# caluculating...6%finished5.63639613774
# caluculating...6%finished5.64070221794
# caluculating...6%finished5.64795047618
# caluculating...6%finished5.65817356655
# caluculating...6%finished5.67139498433
# caluculating...6%finished5.68762988953
# caluculating...6%finished5.70688600006
# caluculating...6%finished5.72916450321
# caluculating...6%finished5.75446094544
# caluculating...6%finished5.78276607557
# caluculating...6%finished5.81406662565
# caluculating...6%finished5.84834602084
# caluculating...6%finished5.8855850158
# caluculating...6%finished5.92576226006
# caluculating...6%finished5.96885479364
# caluculating...6%finished6.0148384793
# caluculating...6%finished6.06368837718
# caluculating...6%finished6.1153790656
# caluculating...6%finished6.16988491508
# caluculating...6%finished6.22718032104
# caluculating...6%finished6.28723989787
# caluculating...6%finished6.35003864212
# caluculating...6%finished6.41555206554
# caluculating...6%finished6.48375630386
# caluculating...6%finished6.5546282035
# caluculating...6%finished6.62814538968
# caluculating...6%finished6.70428631794
# caluculating...6%finished6.7830303116
# caluculating...6%finished6.86617397446
# caluculating...6%finished6.95825711329
# caluculating...7%finished7.05950107113
# caluculating...7%finished11.1829553492
# caluculating...7%finished10.8489940273
# caluculating...7%finished10.5242154418
# caluculating...7%finished10.2086195928
# caluculating...7%finished9.90220648019
# caluculating...7%finished9.60497610407
# caluculating...7%finished9.31692846441
# caluculating...7%finished9.03806356121
# caluculating...7%finished8.76838139445
# caluculating...7%finished8.50788196416
# caluculating...7%finished8.25656527032
# caluculating...7%finished8.01443131293
# caluculating...7%finished7.781480092
# caluculating...7%finished7.55771160753
# caluculating...7%finished7.34312585951
# caluculating...7%finished7.13772284795
# caluculating...7%finished6.94150257284
# caluculating...7%finished6.75446503419
# caluculating...7%finished6.57661023199
# caluculating...7%finished6.40793816625
# caluculating...7%finished6.24844883697
# caluculating...7%finished6.09814224414
# caluculating...7%finished5.95701838776
# caluculating...7%finished5.82507726784
# caluculating...7%finished5.70231888438
# caluculating...7%finished5.58874323737
# caluculating...7%finished5.48435032682
# caluculating...7%finished5.38914015272
# caluculating...7%finished5.30311271508
# caluculating...7%finished5.22626801389
# caluculating...7%finished5.15860604916
# caluculating...7%finished5.10012682088
# caluculating...7%finished5.05083032906
# caluculating...7%finished5.0107165737
# caluculating...7%finished4.97978555479
# caluculating...7%finished4.95803727234
# caluculating...7%finished4.94547172634
# caluculating...7%finished4.9420889168
# caluculating...7%finished4.94788884371
# caluculating...7%finished4.96287150708
# caluculating...7%finished4.9870369069
# caluculating...7%finished5.02038504318
# caluculating...7%finished5.06291591591
# caluculating...7%finished5.1146295251
# caluculating...7%finished5.17552587075
# caluculating...7%finished5.24560495285
# caluculating...7%finished5.32486677141
# caluculating...7%finished5.41331132642
# caluculating...7%finished5.51093861789
# caluculating...7%finished5.61774864581
# caluculating...7%finished5.73374141019
# caluculating...7%finished5.85891691102
# caluculating...7%finished5.99327514831
# caluculating...7%finished6.13681612205
# caluculating...7%finished6.08844369324
# caluculating...7%finished6.16289377033
# caluculating...7%finished6.23732387086
# caluculating...7%finished5.50233693536
# caluculating...7%finished5.47774177139
# caluculating...7%finished5.45499905341
# caluculating...7%finished5.43421444981
# caluculating...7%finished5.41549593252
# caluculating...7%finished5.39895210457
# caluculating...7%finished5.38469029769
# caluculating...7%finished5.37281455947
# caluculating...7%finished5.36342367127
# caluculating...7%finished5.35660934728
# caluculating...7%finished5.3524547466
# caluculating...7%finished5.3510333852
# caluculating...7%finished5.35240849058
# caluculating...7%finished5.35663278644
# caluculating...7%finished5.36374865741
# caluculating...7%finished5.37378861923
# caluculating...7%finished5.38677601077
# caluculating...7%finished5.40272582791
# caluculating...7%finished5.42164562989
# caluculating...7%finished5.44353646404
# caluculating...7%finished5.46839376877
# caluculating...7%finished5.49620822756
# caluculating...7%finished5.5269665593
# caluculating...7%finished5.56065223436
# caluculating...7%finished5.59724611631
# caluculating...7%finished5.63672702937
# caluculating...7%finished5.67907225527
# caluculating...7%finished5.724257965
# caluculating...7%finished5.77225959142
# caluculating...7%finished5.82305214743
# caluculating...7%finished5.87661049684
# caluculating...7%finished5.93290958233
# caluculating...7%finished5.99192461598
# caluculating...7%finished6.053631237
# caluculating...7%finished6.11800564059
# caluculating...7%finished6.18502468159
# caluculating...7%finished6.25466595683
# caluculating...7%finished6.32690786822
# caluculating...7%finished6.40172967013
# caluculating...7%finished6.47911150274
# caluculating...7%finished6.56203933982
# caluculating...7%finished6.65411681474
# caluculating...8%finished6.75535554054
# caluculating...8%finished10.9171674142
# caluculating...8%finished10.5832060923
# caluculating...8%finished10.2584275068
# caluculating...8%finished9.94283165776
# caluculating...8%finished9.63641854518
# caluculating...8%finished9.33918816907
# caluculating...8%finished9.0511405294
# caluculating...8%finished8.7722756262
# caluculating...8%finished8.50259345945
# caluculating...8%finished8.24209402915
# caluculating...8%finished7.99077733531
# caluculating...8%finished7.74864337792
# caluculating...8%finished7.51569215699
# caluculating...8%finished7.29192367252
# caluculating...8%finished7.0773379245
# caluculating...8%finished6.87193491294
# caluculating...8%finished6.67571463783
# caluculating...8%finished6.48867709918
# caluculating...8%finished6.31082229698
# caluculating...8%finished6.14215023124
# caluculating...8%finished5.98266090196
# caluculating...8%finished5.83235430913
# caluculating...8%finished5.69123045275
# caluculating...8%finished5.55928933283
# caluculating...8%finished5.43653094937
# caluculating...8%finished5.32295530236
# caluculating...8%finished5.21856239181
# caluculating...8%finished5.12335221771
# caluculating...8%finished5.03732478007
# caluculating...8%finished4.96048007888
# caluculating...8%finished4.89281811415
# caluculating...8%finished4.83433888587
# caluculating...8%finished4.78504239405
# caluculating...8%finished4.74492863869
# caluculating...8%finished4.71399761978
# caluculating...8%finished4.69224933733
# caluculating...8%finished4.67968379133
# caluculating...8%finished4.67630098179
# caluculating...8%finished4.6821009087
# caluculating...8%finished4.69708357207
# caluculating...8%finished4.72124897189
# caluculating...8%finished4.75459710817
# caluculating...8%finished4.7971279809
# caluculating...8%finished4.84884159009
# caluculating...8%finished4.90973793574
# caluculating...8%finished4.97981701784
# caluculating...8%finished5.0590788364
# caluculating...8%finished5.14752339141
# caluculating...8%finished5.24515068288
# caluculating...8%finished5.3519607108
# caluculating...8%finished5.46795347518
# caluculating...8%finished5.59312897601
# caluculating...8%finished5.7274872133
# caluculating...8%finished5.72722030653
# caluculating...8%finished5.80050432518
# caluculating...8%finished5.87302407135
# caluculating...8%finished5.94570458219
# caluculating...8%finished5.22276295128
# caluculating...8%finished5.19867702935
# caluculating...8%finished5.17639879336
# caluculating...8%finished5.15603243138
# caluculating...8%finished5.13768463472
# caluculating...8%finished5.12146294618
# caluculating...8%finished5.10747386353
# caluculating...8%finished5.09582081343
# caluculating...8%finished5.08660214102
# caluculating...8%finished5.07990926881
# caluculating...8%finished5.07582516374
# caluculating...8%finished5.07442320647
# caluculating...8%finished5.07576651076
# caluculating...8%finished5.07990768424
# caluculating...8%finished5.08688897971
# caluculating...8%finished5.09674276318
# caluculating...8%finished5.10949221096
# caluculating...8%finished5.12515215404
# caluculating...8%finished5.14372999741
# caluculating...8%finished5.16522665821
# caluculating...8%finished5.18963748137
# caluculating...8%finished5.21695310472
# caluculating...8%finished5.2471602575
# caluculating...8%finished5.28024248336
# caluculating...8%finished5.31618078602
# caluculating...8%finished5.35495419881
# caluculating...8%finished5.39654028209
# caluculating...8%finished5.44091555391
# caluculating...8%finished5.48805586004
# caluculating...8%finished5.53793668959
# caluculating...8%finished5.59053344104
# caluculating...8%finished5.64582164662
# caluculating...8%finished5.70377715754
# caluculating...8%finished5.76437629688
# caluculating...8%finished5.82759598332
# caluculating...8%finished5.89341382994
# caluculating...8%finished5.96180822149
# caluculating...8%finished6.03275837291
# caluculating...8%finished6.10624437198
# caluculating...8%finished6.18233522182
# caluculating...8%finished6.26524953252
# caluculating...8%finished6.35732131699
# caluculating...9%finished6.45855479501
# caluculating...9%finished10.6587256684
# caluculating...9%finished10.3247643464
# caluculating...9%finished9.99998576094
# caluculating...9%finished9.68438991191
# caluculating...9%finished9.37797679934
# caluculating...9%finished9.08074642322
# caluculating...9%finished8.79269878356
# caluculating...9%finished8.51383388035
# caluculating...9%finished8.2441517136
# caluculating...9%finished7.9836522833
# caluculating...9%finished7.73233558946
# caluculating...9%finished7.49020163208
# caluculating...9%finished7.25725041115
# caluculating...9%finished7.03348192668
# caluculating...9%finished6.81889617866
# caluculating...9%finished6.6134931671
# caluculating...9%finished6.41727289199
# caluculating...9%finished6.23023535334
# caluculating...9%finished6.05238055114
# caluculating...9%finished5.8837084854
# caluculating...9%finished5.72421915611
# caluculating...9%finished5.57391256328
# caluculating...9%finished5.43278870691
# caluculating...9%finished5.30084758699
# caluculating...9%finished5.17808920352
# caluculating...9%finished5.06451355652
# caluculating...9%finished4.96012064596
# caluculating...9%finished4.86491047187
# caluculating...9%finished4.77888303422
# caluculating...9%finished4.70203833304
# caluculating...9%finished4.63437636831
# caluculating...9%finished4.57589714003
# caluculating...9%finished4.52660064821
# caluculating...9%finished4.48648689285
# caluculating...9%finished4.45555587394
# caluculating...9%finished4.43380759148
# caluculating...9%finished4.42124204548
# caluculating...9%finished4.41785923594
# caluculating...9%finished4.42365916285
# caluculating...9%finished4.43864182622
# caluculating...9%finished4.46280722605
# caluculating...9%finished4.49615536233
# caluculating...9%finished4.53868623506
# caluculating...9%finished4.59039984425
# caluculating...9%finished4.6512961899
# caluculating...9%finished4.721375272
# caluculating...9%finished4.80063709055
# caluculating...9%finished4.88908164556
# caluculating...9%finished4.98670893703
# caluculating...9%finished5.09351896495
# caluculating...9%finished5.20951172933
# caluculating...9%finished5.33468723017
# caluculating...9%finished5.46904546746
# caluculating...9%finished5.44833923324
# caluculating...9%finished5.51950184747
# caluculating...9%finished5.59013620802
# caluculating...9%finished4.97573214904
# caluculating...9%finished4.95049697296
# caluculating...9%finished4.92692589213
# caluculating...9%finished4.90511754017
# caluculating...9%finished4.88517454775
# caluculating...9%finished4.86720224474
# caluculating...9%finished4.85130703241
# caluculating...9%finished4.83759449578
# caluculating...9%finished4.8261673673
# caluculating...9%finished4.81712349038
# caluculating...9%finished4.8105539391
# caluculating...9%finished4.80654143994
# caluculating...9%finished4.80515919898
# caluculating...9%finished4.80647018496
# caluculating...9%finished4.81052686457
# caluculating...9%finished4.81737134102
# caluculating...9%finished4.82703581843
# caluculating...9%finished4.83954330482
# caluculating...9%finished4.8549084659
# caluculating...9%finished4.87313855778
# caluculating...9%finished4.89423437834
# caluculating...9%finished4.91819119525
# caluculating...9%finished4.94499962162
# caluculating...9%finished4.97464642309
# caluculating...9%finished5.00711524636
# caluculating...9%finished5.04238726877
# caluculating...9%finished5.0804417694
# caluculating...9%finished5.12125662604
# caluculating...9%finished5.16480874485
# caluculating...9%finished5.21107442699
# caluculating...9%finished5.26002968055
# caluculating...9%finished5.3116504826
# caluculating...9%finished5.36591299818
# caluculating...9%finished5.42279376071
# caluculating...9%finished5.48226981941
# caluculating...9%finished5.54431885778
# caluculating...9%finished5.60891928708
# caluculating...9%finished5.6760503185
# caluculating...9%finished5.74569201662
# caluculating...9%finished5.81782533786
# caluculating...9%finished5.89289641481
# caluculating...9%finished5.97580451127
# caluculating...9%finished6.0678705805
# caluculating...10%finished6.16909879674
# caluculating...10%finished10.4076301117
# caluculating...10%finished10.0736687897
# caluculating...10%finished9.74889020426
# caluculating...10%finished9.43329435523
# caluculating...10%finished9.12688124266
# caluculating...10%finished8.82965086654
# caluculating...10%finished8.54160322688
# caluculating...10%finished8.26273832367
# caluculating...10%finished7.99305615692
# caluculating...10%finished7.73255672662
# caluculating...10%finished7.48124003278
# caluculating...10%finished7.2391060754
# caluculating...10%finished7.00615485447
# caluculating...10%finished6.78238637
# caluculating...10%finished6.56780062198
# caluculating...10%finished6.36239761041
# caluculating...10%finished6.16617733531
# caluculating...10%finished5.97913979666
# caluculating...10%finished5.80128499446
# caluculating...10%finished5.63261292872
# caluculating...10%finished5.47312359943
# caluculating...10%finished5.3228170066
# caluculating...10%finished5.18169315023
# caluculating...10%finished5.04975203031
# caluculating...10%finished4.92699364684
# caluculating...10%finished4.81341799984
# caluculating...10%finished4.70902508928
# caluculating...10%finished4.61381491519
# caluculating...10%finished4.52778747754
# caluculating...10%finished4.45094277636
# caluculating...10%finished4.38328081163
# caluculating...10%finished4.32480158335
# caluculating...10%finished4.27550509153
# caluculating...10%finished4.23539133617
# caluculating...10%finished4.20446031726
# caluculating...10%finished4.1827120348
# caluculating...10%finished4.1701464888
# caluculating...10%finished4.16676367926
# caluculating...10%finished4.17256360617
# caluculating...10%finished4.18754626954
# caluculating...10%finished4.21171166937
# caluculating...10%finished4.24505980565
# caluculating...10%finished4.28759067838
# caluculating...10%finished4.33930428757
# caluculating...10%finished4.40020063322
# caluculating...10%finished4.47027971532
# caluculating...10%finished4.54954153387
# caluculating...10%finished4.63798608888
# caluculating...10%finished4.73561338035
# caluculating...10%finished4.84242340827
# caluculating...10%finished4.95841617265
# caluculating...10%finished5.08359167349
# caluculating...10%finished5.21794991078
# caluculating...10%finished5.17634211621
# caluculating...10%finished5.24544827962
# caluculating...10%finished4.73640999734
# caluculating...10%finished4.71020972373
# caluculating...10%finished4.68553840127
# caluculating...10%finished4.66248781649
# caluculating...10%finished4.64115481364
# caluculating...10%finished4.6216403878
# caluculating...10%finished4.60404842342
# caluculating...10%finished4.5884840969
# caluculating...10%finished4.57505199822
# caluculating...10%finished4.56385408956
# caluculating...10%finished4.55498764271
# caluculating...10%finished4.54854332311
# caluculating...10%finished4.54460356643
# caluculating...10%finished4.5432413618
# caluculating...10%finished4.54451949934
# caluculating...10%finished4.54849027902
# caluculating...10%finished4.55519563542
# caluculating...10%finished4.56466759889
# caluculating...10%finished4.5769290027
# caluculating...10%finished4.5919943478
# caluculating...10%finished4.6098707477
# caluculating...10%finished4.63055889325
# caluculating...10%finished4.65405399266
# caluculating...10%finished4.68034665758
# caluculating...10%finished4.70942371751
# caluculating...10%finished4.7412689545
# caluculating...10%finished4.77586375515
# caluculating...10%finished4.81318768291
# caluculating...10%finished4.85321897471
# caluculating...10%finished4.89593496737
# caluculating...10%finished4.94131246193
# caluculating...10%finished4.98932803058
# caluculating...10%finished5.03995827425
# caluculating...10%finished5.09318003587
# caluculating...10%finished5.14897057559
# caluculating...10%finished5.20730771229
# caluculating...10%finished5.26816993659
# caluculating...10%finished5.33153649883
# caluculating...10%finished5.39738747569
# caluculating...10%finished5.46570381913
# caluculating...10%finished5.53646738953
# caluculating...10%finished5.6108023879
# caluculating...10%finished5.693704233
# caluculating...10%finished5.78576456402
# caluculating...11%finished5.88698750654
# caluculating...11%finished10.1638807442
# caluculating...11%finished9.82991942223
# caluculating...11%finished9.50514083674
# caluculating...11%finished9.18954498772
# caluculating...11%finished8.88313187514
# caluculating...11%finished8.58590149902
# caluculating...11%finished8.29785385936
# caluculating...11%finished8.01898895616
# caluculating...11%finished7.7493067894
# caluculating...11%finished7.48880735911
# caluculating...11%finished7.23749066527
# caluculating...11%finished6.99535670788
# caluculating...11%finished6.76240548695
# caluculating...11%finished6.53863700248
# caluculating...11%finished6.32405125446
# caluculating...11%finished6.1186482429
# caluculating...11%finished5.92242796779
# caluculating...11%finished5.73539042914
# caluculating...11%finished5.55753562694
# caluculating...11%finished5.3888635612
# caluculating...11%finished5.22937423192
# caluculating...11%finished5.07906763909
# caluculating...11%finished4.93794378271
# caluculating...11%finished4.80600266279
# caluculating...11%finished4.68324427933
# caluculating...11%finished4.56966863232
# caluculating...11%finished4.46527572177
# caluculating...11%finished4.37006554767
# caluculating...11%finished4.28403811003
# caluculating...11%finished4.20719340884
# caluculating...11%finished4.13953144411
# caluculating...11%finished4.08105221583
# caluculating...11%finished4.03175572401
# caluculating...11%finished3.99164196865
# caluculating...11%finished3.96071094974
# caluculating...11%finished3.93896266729
# caluculating...11%finished3.92639712129
# caluculating...11%finished3.92301431175
# caluculating...11%finished3.92881423866
# caluculating...11%finished3.94379690203
# caluculating...11%finished3.96796230185
# caluculating...11%finished4.00131043813
# caluculating...11%finished4.04384131086
# caluculating...11%finished4.09555492005
# caluculating...11%finished4.1564512657
# caluculating...11%finished4.2265303478
# caluculating...11%finished4.30579216636
# caluculating...11%finished4.39423672137
# caluculating...11%finished4.49186401284
# caluculating...11%finished4.59867404076
# caluculating...11%finished4.71466680514
# caluculating...11%finished4.83984230597
# caluculating...11%finished4.84309547758
# caluculating...11%finished4.91124773304
# caluculating...11%finished4.97835405937
# caluculating...11%finished4.47757737056
# caluculating...11%finished4.45198827746
# caluculating...11%finished4.42788662855
# caluculating...11%finished4.40536225032
# caluculating...11%finished4.38451012468
# caluculating...11%finished4.3654295308
# caluculating...11%finished4.34822282358
# caluculating...11%finished4.33299386652
# caluculating...11%finished4.31984616969
# caluculating...11%finished4.30888084434
# caluculating...11%finished4.30019451843
# caluculating...11%finished4.29387738488
# caluculating...11%finished4.29001153384
# caluculating...11%finished4.28866969357
# caluculating...11%finished4.28991443945
# caluculating...11%finished4.2937978775
# caluculating...11%finished4.30036175376
# caluculating...11%finished4.30963791184
# caluculating...11%finished4.32164900482
# caluculating...11%finished4.33640936967
# caluculating...11%finished4.35392598465
# caluculating...11%finished4.37419944724
# caluculating...11%finished4.39722492578
# caluculating...11%finished4.42299305535
# caluculating...11%finished4.45149075959
# caluculating...11%finished4.48270198995
# caluculating...11%finished4.51660838059
# caluculating...11%finished4.55318982048
# caluculating...11%finished4.59242494891
# caluculating...11%finished4.63429157908
# caluculating...11%finished4.67876705806
# caluculating...11%finished4.72582856934
# caluculating...11%finished4.77545338452
# caluculating...11%finished4.82761907136
# caluculating...11%finished4.88230366253
# caluculating...11%finished4.93948579145
# caluculating...11%finished4.9991447992
# caluculating...11%finished5.06126081687
# caluculating...11%finished5.12581482683
# caluculating...11%finished5.19278870617
# caluculating...11%finished5.26216525529
# caluculating...11%finished5.33605309435
# caluculating...11%finished5.41894865289
# caluculating...11%finished5.51100322486
# caluculating...12%finished5.6122208838
# caluculating...12%finished9.92747756582
# caluculating...12%finished9.59351624388
# caluculating...12%finished9.26873765839
# caluculating...12%finished8.95314180936
# caluculating...12%finished8.64672869679
# caluculating...12%finished8.34949832067
# caluculating...12%finished8.06145068101
# caluculating...12%finished7.7825857778
# caluculating...12%finished7.51290361105
# caluculating...12%finished7.25240418076
# caluculating...12%finished7.00108748692
# caluculating...12%finished6.75895352953
# caluculating...12%finished6.5260023086
# caluculating...12%finished6.30223382413
# caluculating...12%finished6.08764807611
# caluculating...12%finished5.88224506455
# caluculating...12%finished5.68602478944
# caluculating...12%finished5.49898725079
# caluculating...12%finished5.32113244859
# caluculating...12%finished5.15246038285
# caluculating...12%finished4.99297105356
# caluculating...12%finished4.84266446073
# caluculating...12%finished4.70154060436
# caluculating...12%finished4.56959948444
# caluculating...12%finished4.44684110098
# caluculating...12%finished4.33326545397
# caluculating...12%finished4.22887254342
# caluculating...12%finished4.13366236932
# ...
# caluculating...96%finished16.2955059011
# caluculating...96%finished15.9615445792
# caluculating...96%finished15.6367659937
# caluculating...96%finished15.3211701447
# caluculating...96%finished15.0147570321
# caluculating...96%finished14.717526656
# caluculating...96%finished14.4294790163
# caluculating...96%finished14.1506141131
# caluculating...96%finished13.8809319463
# caluculating...96%finished13.620432516
# caluculating...96%finished13.3691158222
# caluculating...96%finished13.1269818648
# caluculating...96%finished12.8940306439
# caluculating...96%finished12.6702621594
# caluculating...96%finished12.4537185616
# caluculating...96%finished12.2423220693
# caluculating...96%finished12.0361161719
# caluculating...96%finished11.8351474084
# caluculating...96%finished11.6394647144
# caluculating...96%finished11.4491194495
# caluculating...96%finished11.2641654113
# caluculating...96%finished11.0846588332
# caluculating...96%finished10.9106583658
# caluculating...96%finished10.7422250391
# caluculating...96%finished10.5794222052
# caluculating...96%finished10.4223154589
# caluculating...96%finished10.2709725379
# caluculating...96%finished10.1254631998
# caluculating...96%finished9.98585907764
# caluculating...96%finished9.85223351379
# caluculating...96%finished9.72466137403
# caluculating...96%finished9.60321884297
# caluculating...96%finished9.48798320323
# caluculating...96%finished9.37903260098
# caluculating...96%finished9.27644580091
# caluculating...96%finished9.18030193399
# caluculating...96%finished9.09068024139
# caluculating...96%finished9.00765981832
# caluculating...96%finished8.93131936115
# caluculating...96%finished8.86173692134
# caluculating...96%finished8.79898966909
# caluculating...96%finished8.7431536695
# caluculating...96%finished8.69430367352
# caluculating...96%finished8.65251292538
# caluculating...96%finished8.6178529878
# caluculating...96%finished8.59039358571
# caluculating...96%finished8.57020246858
# caluculating...96%finished8.55734529128
# caluculating...96%finished3.67124594289
# caluculating...96%finished3.72902359175
# caluculating...96%finished3.78977440379
# caluculating...96%finished3.85301569529
# caluculating...96%finished3.91838349599
# caluculating...96%finished3.98560487519
# caluculating...96%finished4.05447400272
# caluculating...96%finished4.12483387438
# caluculating...96%finished4.19656306817
# caluculating...96%finished4.26956632348
# caluculating...96%finished4.34376785212
# caluculating...96%finished4.41910655741
# caluculating...96%finished4.49553258078
# caluculating...96%finished4.57300477528
# caluculating...96%finished4.65158473562
# caluculating...96%finished4.73641009309
# caluculating...96%finished4.83041818701
# caluculating...96%finished4.9336090174
# caluculating...96%finished5.04598258423
# caluculating...96%finished5.16753888752
# caluculating...96%finished5.29827792727
# caluculating...96%finished5.96258693632
# caluculating...96%finished6.05899042272
# caluculating...96%finished6.15584358
# caluculating...96%finished6.25316204089
# caluculating...96%finished6.35095938599
# caluculating...96%finished6.44924747509
# caluculating...96%finished6.54803671149
# caluculating...96%finished6.64733625584
# caluculating...96%finished6.74715420052
# caluculating...96%finished6.84749771357
# caluculating...96%finished6.94837315796
# caluculating...96%finished7.04978619174
# caluculating...96%finished7.15174185248
# caluculating...96%finished7.25424462887
# caluculating...96%finished7.35729852198
# caluculating...96%finished7.46090709791
# caluculating...96%finished7.56507353328
# caluculating...96%finished7.66980065474
# caluculating...96%finished7.77509097348
# caluculating...96%finished7.88094671536
# caluculating...96%finished7.98736984766
# caluculating...96%finished8.09436210246
# caluculating...96%finished8.20192499768
# caluculating...96%finished8.31005985548
# caluculating...96%finished8.41876781897
# caluculating...96%finished8.52804986698
# caluculating...96%finished8.63790682751
# caluculating...96%finished8.74833938976
# caluculating...96%finished8.85934811487
# caluculating...96%finished8.97093344591
# caluculating...97%finished9.08309571666
# caluculating...97%finished16.6835288017
# caluculating...97%finished16.3495674798
# caluculating...97%finished16.0247888943
# caluculating...97%finished15.7091930453
# caluculating...97%finished15.4027799327
# caluculating...97%finished15.1055495566
# caluculating...97%finished14.8175019169
# caluculating...97%finished14.5386370137
# caluculating...97%finished14.268954847
# caluculating...97%finished14.0084554167
# caluculating...97%finished13.7571387228
# caluculating...97%finished13.5150047654
# caluculating...97%finished13.2820535445
# caluculating...97%finished13.0578979827
# caluculating...97%finished12.8395389633
# caluculating...97%finished12.6263791846
# caluculating...97%finished12.4184640699
# caluculating...97%finished12.2158413481
# caluculating...97%finished12.0185610816
# caluculating...97%finished11.8266756818
# caluculating...97%finished11.6402399102
# caluculating...97%finished11.4593108634
# caluculating...97%finished11.2839479416
# caluculating...97%finished11.1142127985
# caluculating...97%finished10.9501692716
# caluculating...97%finished10.7918832926
# caluculating...97%finished10.6394227766
# caluculating...97%finished10.4928574918
# caluculating...97%finished10.3522589081
# caluculating...97%finished10.2177000268
# caluculating...97%finished10.0892551929
# caluculating...97%finished9.96699989078
# caluculating...97%finished9.85101052671
# caluculating...97%finished9.74136420018
# caluculating...97%finished9.63813846712
# caluculating...97%finished9.54141109837
# caluculating...97%finished9.45125983641
# caluculating...97%finished9.36776215391
# caluculating...97%finished9.29099501697
# caluculating...97%finished9.22103465628
# caluculating...97%finished9.15795634873
# caluculating...97%finished9.10183421173
# caluculating...97%finished9.05274101225
# caluculating...97%finished9.01074799192
# caluculating...97%finished8.97592470908
# caluculating...97%finished8.94833889837
# caluculating...97%finished8.92805634778
# caluculating...97%finished8.91514079281
# caluculating...97%finished3.90156454532
# caluculating...97%finished3.96051967724
# caluculating...97%finished4.02262258759
# caluculating...97%finished4.08735860158
# caluculating...97%finished4.15433529942
# caluculating...97%finished4.22325660251
# caluculating...97%finished4.29389858202
# caluculating...97%finished4.36609028276
# caluculating...97%finished4.43969953741
# caluculating...97%finished4.51462275785
# caluculating...97%finished4.59077764029
# caluculating...97%finished4.66809793422
# caluculating...97%finished4.74652965811
# caluculating...97%finished4.82602832952
# caluculating...97%finished4.90655691389
# caluculating...97%finished4.99142124355
# caluculating...97%finished5.08542933748
# caluculating...97%finished5.18862016786
# caluculating...97%finished5.3009937347
# caluculating...97%finished5.42255003799
# caluculating...97%finished5.55329827394
# caluculating...97%finished6.24913643342
# caluculating...97%finished6.34791327875
# caluculating...97%finished6.4471263552
# caluculating...97%finished6.54679259561
# caluculating...97%finished6.64692668955
# caluculating...97%finished6.74754145119
# caluculating...97%finished6.84864811179
# caluculating...97%finished6.95025655525
# caluculating...97%finished7.05237550989
# caluculating...97%finished7.15501270586
# caluculating...97%finished7.25817500575
# caluculating...97%finished7.36186851371
# caluculating...97%finished7.46609866721
# caluculating...97%finished7.57087031491
# caluculating...97%finished7.67618778296
# caluculating...97%finished7.78205493214
# caluculating...97%finished7.88847520674
# caluculating...97%finished7.99545167744
# caluculating...97%finished8.10298707825
# caluculating...97%finished8.21108383917
# caluculating...97%finished8.31974411469
# caluculating...97%finished8.42896980907
# caluculating...97%finished8.53876259877
# caluculating...97%finished8.64912395226
# caluculating...97%finished8.76005514779
# caluculating...97%finished8.87155728935
# caluculating...97%finished8.98363132088
# caluculating...97%finished9.09627803903
# caluculating...97%finished9.20949810498
# caluculating...97%finished9.32329205466
# caluculating...98%finished9.43766030843
# caluculating...98%finished17.0788978915
# caluculating...98%finished16.7449365696
# caluculating...98%finished16.4201579841
# caluculating...98%finished16.1045621351
# caluculating...98%finished15.7981490225
# caluculating...98%finished15.5009186464
# caluculating...98%finished15.2128710067
# caluculating...98%finished14.9340061035
# caluculating...98%finished14.6643239367
# caluculating...98%finished14.4038245065
# caluculating...98%finished14.1525078126
# caluculating...98%finished13.9103738552
# caluculating...98%finished13.6774226343
# caluculating...98%finished13.4520553756
# caluculating...98%finished13.2319184485
# caluculating...98%finished13.0170336777
# caluculating...98%finished12.8074476475
# caluculating...98%finished12.6032091903
# caluculating...98%finished12.404369403
# caluculating...98%finished12.2109816505
# caluculating...98%finished12.023101555
# caluculating...98%finished11.8407869687
# caluculating...98%finished11.6640979311
# caluculating...98%finished11.4930966067
# caluculating...98%finished11.3278472054
# caluculating...98%finished11.1684158826
# caluculating...98%finished11.0148706212
# caluculating...98%finished10.8672810934
# caluculating...98%finished10.7257185054
# caluculating...98%finished10.5902554242
# caluculating...98%finished10.4609655893
# caluculating...98%finished10.3379237108
# caluculating...98%finished10.2212052556
# caluculating...98%finished10.110886226
# caluculating...98%finished10.0070429319
# caluculating...98%finished9.90975176005
# caluculating...98%finished9.81908894381
# caluculating...98%finished9.73513033626
# caluculating...98%finished9.65795118896
# caluculating...98%finished9.58762593952
# caluculating...98%finished9.52422801018
# caluculating...98%finished9.46782961904
# caluculating...98%finished9.41850160591
# caluculating...98%finished9.37631327356
# caluculating...98%finished9.34133224516
# caluculating...98%finished9.31362433831
# caluculating...98%finished9.29325345532
# caluculating...98%finished9.28028148934
# caluculating...98%finished4.13902367152
# caluculating...98%finished4.19910517705
# caluculating...98%finished4.26251485344
# caluculating...98%finished4.32870703967
# caluculating...98%finished4.39726048335
# caluculating...98%finished4.46785504283
# caluculating...98%finished4.54024770418
# caluculating...98%finished4.6142526864
# caluculating...98%finished4.68972635888
# caluculating...98%finished4.7665562362
# caluculating...98%finished4.84465305288
# caluculating...98%finished4.92394505586
# caluculating...98%finished5.0043738669
# caluculating...98%finished5.08589145257
# caluculating...98%finished5.16845787979
# caluculating...98%finished5.25377858318
# caluculating...98%finished5.34778667711
# caluculating...98%finished5.45098536412
# caluculating...98%finished5.5633593994
# caluculating...98%finished5.68490737762
# caluculating...98%finished5.81565567933
# caluculating...98%finished5.95556819357
# caluculating...98%finished6.64354042847
# caluculating...98%finished6.74511923681
# caluculating...98%finished6.847138549
# caluculating...98%finished6.94961423655
# caluculating...98%finished7.0525601275
# caluculating...98%finished7.1559883302
# caluculating...98%finished7.25990949289
# caluculating...98%finished7.36433301425
# caluculating...98%finished7.46926721588
# caluculating...98%finished7.57471948514
# caluculating...98%finished7.68069639376
# caluculating...98%finished7.78720379789
# caluculating...98%finished7.89424692239
# caluculating...98%finished8.00183043291
# caluculating...98%finished8.10995849731
# caluculating...98%finished8.21863483879
# caluculating...98%finished8.32786278182
# caluculating...98%finished8.43764529213
# caluculating...98%finished8.54798501162
# caluculating...98%finished8.65888428915
# caluculating...98%finished8.77034520745
# caluculating...98%finished8.8823696073
# caluculating...98%finished8.99495910866
# caluculating...98%finished9.10811512964
# caluculating...98%finished9.22183890367
# caluculating...98%finished9.33613149445
# caluculating...98%finished9.45099380985
# caluculating...98%finished9.56642661416
# caluculating...98%finished9.68243053926
# caluculating...99%finished9.79900609479
# caluculating...99%finished17.4816131705
# caluculating...99%finished17.1476518485
# caluculating...99%finished16.822873263
# caluculating...99%finished16.507277414
# caluculating...99%finished16.2008643014
# caluculating...99%finished15.9036339253
# caluculating...99%finished15.6155862857
# caluculating...99%finished15.3367213824
# caluculating...99%finished15.0670392157
# caluculating...99%finished14.8065397854
# caluculating...99%finished14.5552230916
# caluculating...99%finished14.3130891342
# caluculating...99%finished14.0798939905
# caluculating...99%finished13.8527573624
# caluculating...99%finished13.6308803383
# caluculating...99%finished13.4143084153
# caluculating...99%finished13.2030892581
# caluculating...99%finished12.9972727156
# caluculating...99%finished12.7969108266
# caluculating...99%finished12.6020578124
# caluculating...99%finished12.4127700542
# caluculating...99%finished12.2291060555
# caluculating...99%finished12.0511263876
# caluculating...99%finished11.8788936179
# caluculating...99%finished11.7124722208
# caluculating...99%finished11.5519284694
# caluculating...99%finished11.3973303109
# caluculating...99%finished11.2487472234
# caluculating...99%finished11.1062500573
# caluculating...99%finished10.9699108606
# caluculating...99%finished10.8398026922
# caluculating...99%finished10.7159994222
# caluculating...99%finished10.5985755246
# caluculating...99%finished10.4876058623
# caluculating...99%finished10.3831654696
# caluculating...99%finished10.2853293323
# caluculating...99%finished10.1941721706
# caluculating...99%finished10.109768226
# caluculating...99%finished10.0321910552
# caluculating...99%finished9.96151333345
# caluculating...99%finished9.89780666865
# caluculating...99%finished9.84114142874
# caluculating...99%finished9.79158658283
# caluculating...99%finished9.74920955731
# caluculating...99%finished9.71407610741
# caluculating...99%finished9.68625020421
# caluculating...99%finished9.66579393689
# caluculating...99%finished9.65276742972
# caluculating...99%finished4.38363604173
# caluculating...99%finished4.44479257336
# caluculating...99%finished4.50946260807
# caluculating...99%finished4.57707102127
# caluculating...99%finished4.64716766337
# caluculating...99%finished4.71940755699
# caluculating...99%finished4.79352765724
# caluculating...99%finished4.86932647653
# caluculating...99%finished4.9466481804
# caluculating...99%finished5.02537079106
# caluculating...99%finished5.10539761138
# caluculating...99%finished5.18665101699
# caluculating...99%finished5.26906794338
# caluculating...99%finished5.35259657741
# caluculating...99%finished5.43719390574
# caluculating...99%finished5.52348211198
# caluculating...99%finished5.61749020591
# caluculating...99%finished5.72068103629
# caluculating...99%finished5.83305460312
# caluculating...99%finished5.95461090642
# caluculating...99%finished6.08534994616
# caluculating...99%finished6.22527172237
# caluculating...99%finished6.94586953256
# caluculating...99%finished7.04982010187
# caluculating...99%finished7.15419796341
# caluculating...99%finished7.25902024917
# caluculating...99%finished7.36430186522
# caluculating...99%finished7.47005584971
# caluculating...99%finished7.57629365895
# caluculating...99%finished7.68302539875
# caluculating...99%finished7.79026001342
# caluculating...99%finished7.89800544153
# caluculating...99%finished8.00626874522
# caluculating...99%finished8.11505621907
# caluculating...99%finished8.22437348126
# caluculating...99%finished8.33422555191
# caluculating...99%finished8.44461691919
# caluculating...99%finished8.55555159684
# caluculating...99%finished8.66703317343
# caluculating...99%finished8.77906485557
# caluculating...99%finished8.89164950529
# caluculating...99%finished9.00478967312
# caluculating...99%finished9.11848762693
# caluculating...99%finished9.23274537772
# caluculating...99%finished9.34756470235
# caluculating...99%finished9.46294716375
# caluculating...99%finished9.57889412911
# caluculating...99%finished9.69540678602
# caluculating...99%finished9.8124861572
# caluculating...99%finished9.93013311351
# caluculating...99%finished10.0483483858
# caluculating...100%finished10.1671325759
# finish caluculation!

# %%
shapeSence.showHeatMap()
