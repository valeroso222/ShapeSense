# %%
np.random.seed(1)

df = pd.DataFrame({'Area_A': list([correaction_List[i][0] for i in range(11)]), 
                   'Area_B': list([correaction_List[i][1] for i in range(11)]),
                   'Area_C': list([correaction_List[i][2] for i in range(11)]), 
                   'cog_A': list([correaction_List[i][3] for i in range(11)]), 
                   'cog_C': list([correaction_List[i][4] for i in range(11)]), 
                   'Mh_A': list([correaction_List[i][5] for i in range(11)]),
                   'Mw_B': list([correaction_List[i][6] for i in range(11)]),
                   'M_u_A': list([correaction_List[i][7] for i in range(11)]),
                   'M_u_B': list([correaction_List[i][8] for i in range(11)]),
                   'M_u_C': list([correaction_List[i][9] for i in range(11)]),
                   'M_v_A': list([correaction_List[i][10] for i in range(11)]),
                   'M_v_B': list([correaction_List[i][11] for i in range(11)]),
                   'M_v_C': list([correaction_List[i][12] for i in range(11)]),
                   'Average': list(np.average(correaction_List, axis=1))},
                 index=['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','Average'],
                 columns=['Area_A','Area_B','Area_C','cog_A','cog_C','Mh_A','Mw_B','M_u_A','M_u_B','M_u_C','M_v_A','M_v_B','M_v_C','Average'])
type(df.style)
# pandas.core.style.Styler

df.style.background_gradient(cmap='winter')
df.round(2)
# Out:
#          Area_A  Area_B  Area_C  cog_A  cog_C  Mh_A  Mw_B  M_u_A  M_u_B  \
# p1         0.72     1.0    0.99   0.21  -0.50 -0.76  0.75   0.50   -1.0
# p2         0.63     1.0    0.94  -0.57  -0.65 -0.69  0.41   0.77    1.0
# p3         0.19    -1.0    0.63   0.23   0.87 -0.50  0.46   0.65   -1.0
# p4         0.70     1.0    0.95  -0.31  -0.50 -0.50  0.23   0.87    1.0
# p5         0.24     1.0    0.57  -0.40   0.87 -0.21  0.29   0.65   -1.0
# p6         0.43     1.0    0.87   0.70   0.98 -0.60 -0.37  -0.78    1.0
# p7         0.84     1.0    0.91  -0.05  -1.00  0.72 -0.79  -0.57    1.0
# p8         0.55     1.0    0.99  -0.22   0.24  1.00  0.12  -0.50   -1.0
# p9         0.68     1.0    0.29   0.39  -0.69  0.65  0.28  -0.45    1.0
# p10        0.62     1.0    1.00   0.31   0.50  0.87  0.28  -0.83   -1.0
# Average    0.56     0.8    0.81   0.03   0.01 -0.00  0.17   0.03    0.0
#
#          M_u_C  M_v_A  M_v_B  M_v_C  Average
# p1        0.74    1.0  -0.73   0.97     0.40
# ...

# %%
type(df.style)
# pandas.core.style.Styler

df.round(2).style.background_gradient(cmap='winter', low=2.)
# Out:
# <style  type="text/css" >
#     #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col0 {
#             background-color:  #00f087;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col1 {
#             background-color:  #00ff80;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col2 {
#             background-color:  #00fe80;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col3 {
#             background-color:  #00df90;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col4 {
#             background-color:  #00c09f;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col5 {
#             background-color:  #00aaaa;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col6 {
#             background-color:  #00ff80;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col7 {
#             background-color:  #00ed88;
#         }    #T_db26b28a_e881_11e8_bce0_e8340f027f64row0_col8 {
#             background-color:  #00aaaa;
# ...
