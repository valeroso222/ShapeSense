# %%
np.random.seed(1)

df = pd.DataFrame({'Area_A': list([correaction_List[i][0] for i in range(11)]), 
                   'Area_B': list([correaction_List[i][1] for i in range(11)]),
                   'Area_C': list([correaction_List[i][2] for i in range(11)]), 
                   'cog_A': list([correaction_List[i][3] for i in range(11)]), 
                   'cog_C': list([correaction_List[i][4] for i in range(11)]), 
                   'Mh_A': list([correaction_List[i][5] for i in range(11)]),
                   'Mw_B': list([correaction_List[i][6] for i in range(11)]),
                   'M_u_A': list([correaction_List[i][7] for i in range(11)]),
                   'M_u_B': list([correaction_List[i][8] for i in range(11)]),
                   'M_u_C': list([correaction_List[i][9] for i in range(11)]),
                   'M_v_A': list([correaction_List[i][10] for i in range(11)]),
                   'M_v_B': list([correaction_List[i][11] for i in range(11)]),
                   'M_v_C': list([correaction_List[i][12] for i in range(11)]),
                   'Average': list(np.average(correaction_List, axis=1))},
                 index=['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','Average'],
                 columns=['Area_A','Area_B','Area_C','cog_A','cog_C','Mh_A','Mw_B','M_u_A','M_u_B','M_u_C','M_v_A','M_v_B','M_v_C','Average'])
type(df.style)
# pandas.core.style.Styler

df.style.background_gradient(cmap='winter')
df.round(2)
# Out:
#          Area_A  Area_B  Area_C  cog_A  cog_C  Mh_A  Mw_B  M_u_A  M_u_B  \
# p1         0.70    0.86    0.49  -0.33   0.52  0.42  0.86   0.48   0.80
# p2         0.27    0.02   -0.65   0.65   0.33  0.36 -0.29   0.71   0.03
# p3         0.65    0.86   -0.43   0.23  -0.85  0.75  0.33   0.87   0.56
# p4        -0.05   -0.57    0.24   0.78  -0.35  0.08 -0.95   0.38  -0.46
# p5         0.07    0.67    0.28  -0.37  -0.15 -0.21  0.31  -0.38   0.32
# p6         0.91    0.44    0.70   0.29   0.87 -0.09 -0.12   0.79  -0.20
# p7         0.71    0.75    0.23   0.14  -0.92  0.64 -0.28   0.82   0.31
# p8         0.08   -0.35    0.76   0.18  -0.71  0.52  0.44   0.66  -0.08
# p9         0.80    0.76    0.80   0.37  -0.20  0.82  0.49   0.84   0.47
# p10        0.77    0.66    0.89   0.03  -0.30  0.77  0.79   0.74   0.63
# Average    0.49    0.41    0.33   0.20  -0.18  0.41  0.16   0.59   0.24
#
#          M_u_C  M_v_A  M_v_B  M_v_C  Average
# p1       -0.82   0.71   0.96   0.58     0.48
# ...

# %%
type(df.style)
# pandas.core.style.Styler

df.round(2).style.background_gradient(cmap='winter', low=2.)
# Out:
# <style  type="text/css" >
#     #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col0 {
#             background-color:  #00ed88;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col1 {
#             background-color:  #00ff80;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col2 {
#             background-color:  #00e98b;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col3 {
#             background-color:  #00ada8;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col4 {
#             background-color:  #00ef88;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col5 {
#             background-color:  #00de90;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col6 {
#             background-color:  #00ff80;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col7 {
#             background-color:  #00e58c;
#         }    #T_17ae8cd4_ddd4_11e8_8fce_9eb97ac5f79drow0_col8 {
#             background-color:  #00ff80;
# ...
