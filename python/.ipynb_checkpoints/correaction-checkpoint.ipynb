# %%
correaction_List=np.round(correaction_List,decimals=2)

# %%
np.random.seed(1)

df = pd.DataFrame({'Area_A': list([correaction_List[i][0] for i in range(11)]), 
                   'Area_B': list([correaction_List[i][1] for i in range(11)]),
                   'Area_C': list([correaction_List[i][2] for i in range(11)]), 
                   'cog_A': list([correaction_List[i][3] for i in range(11)]), 
                   'cog_C': list([correaction_List[i][4] for i in range(11)]), 
                   'Mh_A': list([correaction_List[i][5] for i in range(11)]),
                   'Mw_B': list([correaction_List[i][6] for i in range(11)]),
                   'M_u_A': list([correaction_List[i][7] for i in range(11)]),
                   'M_u_B': list([correaction_List[i][8] for i in range(11)]),
                   'M_u_C': list([correaction_List[i][9] for i in range(11)]),
                   'M_v_A': list([correaction_List[i][10] for i in range(11)]),
                   'M_v_B': list([correaction_List[i][11] for i in range(11)]),
                   'M_v_C': list([correaction_List[i][12] for i in range(11)]),
                   'Average': list(np.average(correaction_List, axis=1))},
                 index=['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','Average'],
                 columns=['Area_A','Area_B','Area_C','cog_A','cog_C','Mh_A','Mw_B','M_u_A','M_u_B','M_u_C','M_v_A','M_v_B','M_v_C','Average'])
type(df.style)
# pandas.core.style.Styler

df.style.background_gradient(cmap='winter')
df.round(2)
# Out:
#          Area_A  Area_B  Area_C  cog_A  cog_C  Mh_A  Mw_B  M_u_A  M_u_B  \
# p1         0.70    0.87    0.53  -0.32   0.63  0.55  0.42   0.86   0.40
# p2         0.26   -0.05   -0.66   0.66   0.51  0.31  0.36  -0.28   0.77
# p3         0.66    0.84   -0.40   0.25  -0.20 -0.86  0.75   0.36   0.83
# p4        -0.07   -0.61    0.25   0.79   0.72 -0.34  0.08  -0.96   0.38
# p5         0.03    0.55    0.29  -0.37   0.44 -0.13 -0.21   0.26  -0.43
# p6         0.91    0.40    0.73   0.24   0.03  0.86 -0.09  -0.20   0.67
# p7         0.77    0.75    0.31   0.18  -0.39 -0.92  0.64  -0.24   0.77
# p8         0.12   -0.42    0.76   0.18  -0.48 -0.63  0.52   0.39   0.61
# p9         0.81    0.78    0.80   0.38  -0.99 -0.16  0.82   0.50   0.80
# p10        0.68    0.63    0.88   0.04   0.03 -0.34  0.77   0.74   0.62
# Average    0.49    0.37    0.35   0.20   0.03 -0.17  0.41   0.14   0.54
#
#          M_u_C  M_v_A  M_v_B  M_v_C  Average
# p1        0.70  -0.65   0.71   0.96     0.50
# ...

# %%
type(df.style)
# pandas.core.style.Styler

df.round(2).style.background_gradient(cmap='winter', low=2.)
# Out:
# <style  type="text/css" >
#     #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col0 {
#             background-color:  #00ed88;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col1 {
#             background-color:  #00ff80;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col2 {
#             background-color:  #00ec89;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col3 {
#             background-color:  #00aea8;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col4 {
#             background-color:  #00fb82;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col5 {
#             background-color:  #00f186;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col6 {
#             background-color:  #00de90;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col7 {
#             background-color:  #00ff80;
#         }    #T_09636236_dda5_11e8_8acd_9eb97ac5f79drow0_col8 {
#             background-color:  #00e28e;
# ...
